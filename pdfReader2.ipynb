# %%
import pdfplumber
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import os

# Preprocessing: load stopwords
stop_words = set(stopwords.words('english'))

# Function to preprocess text (remove punctuation, lowercase, tokenize, and remove stopwords)
def preprocess_text(text):
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'\W+', ' ', text)  # Remove punctuation
    words = word_tokenize(text)  # Tokenize
    words = [w for w in words if w not in stop_words]  # Remove stopwords
    return words

# Function to extract text from text-based PDF using pdfplumber
def extract_text_from_pdf(pdf_path):
    all_text = ""
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            text = page.extract_text()
            if text:
                all_text += text + "\n"
    return all_text

# Function to extract headings and descriptions from resume text
def extract_headings_and_descriptions(text):
    # Updated regex patterns for headings (no need for a colon after headings)
    heading_patterns = [
        r"\beducation\b",  
        r"\bexperience\b",  
        r"\bprojects\b",  
        # r"\btechnical\s*skills\b",  
        r"\bskills\b",
        r"\bpositions\s*of\s*responsibility\b",  
        r"\bcertifications\b",  
        r"\bmiscellaneous\b"
    ]
    
    # Join the patterns into a single regex with case-insensitive matching
    heading_regex = re.compile(r"(?P<heading>(" + "|".join(heading_patterns) + r"))\s*(?:$|\n)", re.IGNORECASE)
    
    # Split text based on headings
    sections = heading_regex.split(text)
    
    result = {}
    
    for i in range(0, len(sections)):
        # If the current section matches a heading (non-None and non-empty)
        if sections[i] and heading_regex.match(sections[i].strip()):
            heading = sections[i].strip()
            # Get the next section as content, ensuring it's not None
            if i + 1 < len(sections) and sections[i + 1]:
                content = sections[i + 1].strip()
                processed_content = preprocess_text(content)
                result[heading] = processed_content
    return result

# Main function to handle text-based PDFs
def process_pdf(pdf_path):
    # Check if the file is valid
    if not os.path.exists(pdf_path):
        print(f"File {pdf_path} not found!")
        return
    else:
        print(f"Processing file: {pdf_path}")
    
    # Extract text with pdfplumber (for text-based PDFs)
    try:
        extracted_text = extract_text_from_pdf(pdf_path)
        print(f"Extracted Text: {extracted_text[:500]}...")  # Show only first 500 characters for brevity
    except Exception as e:
        print(f"Error extracting text: {e}")
        return

    # Extract headings and descriptions
    heading_to_content = extract_headings_and_descriptions(extracted_text)

    # Display the extracted headings and content
    if heading_to_content:
        for heading, content in heading_to_content.items():
            print(f"Heading: {heading}")
            print(f"Content: {content}")
            print("-" * 40)
    else:
        print("No headings and content extracted.")

# Example usage:
if __name__ == "__main__":
    pdf_path = "202308111555929_dice_resume_cv_madhura_bapat.pdf"  # Replace with the path to your PDF
    process_pdf(pdf_path)
# Out:
# Processing file: 202308111555929_dice_resume_cv_madhura_bapat.pdf
# Extracted Text: Madhura A. Bapat
# Columbus, Ohio Cell: +1 (404) 518 6607
# LinkedIn URL E-mail: madhurabapat1108@gmail.com
# An IT professional with more than 18 years of experience in managing, driving the delivery and solutions across various large client accounts
# through program/project management, technical and solution Architecting. Experienced across Finance, Public Services, Healthcare, Insurance,
# Manufacturing, HR domains. Working experience on integrations, transformations, custom developments, upgrade/migr...
# Heading: CERTIFICATIONS
# Content: ['integration', 'technologies', 'oracle', 'cloud', 'integrations', 'oic', 'databases', 'oracle', 'autonomous', 'database', 'cloud', 'oracle', '19c', 'oci', 'soa', 'cs', 'pcs', 'mft', 'cs', 'oracle', 'cloud', 'erp', 'hcm', 'global', 'hr', 'cs', 'technologies', 'tools', 'aws', 'azure', 'cloud', 'jcs', 'java', 'j2ee', 'premises', 'oracle', 'fusion', 'mw', 'suite', '12c', 'soa', 'osb', 'bpm', 'ejb', 'jsp', 'dev', 'ops', 'tools', 'flexdeploy', 'azure', 'devopns', 'github', 'healthcare', 'b2b', 'adf', 'wc', 'odi', 'bi', 'idm', 'audit', 'vault', '20', 'etc', 'jenkins', 'bmc', 'control', '9', 'ibm', 'workload', 'automation', 'tools', 'applications', 'oracle', 'cloud', 'erp', 'oracle', 'hcm', 'cloud', 'sfdc', 'oracle', 'conversant', 'iot', 'ai', 'blockchain', 'xr', 'technologies', 'cpq', 'cloud', 'informatica', 'mdm', 'cloud', 'ebs', 'prem', 'ps', 'integrations', 'certifications', 'oracle', 'cloud', 'platform', 'application', 'integration', '2020', 'associate', 'oracle', 'infrastructure', 'cloud', 'fundamentals', '2021', 'oracle', 'autonomous', 'database', 'cloud', '2019', 'specialist', 'oracle', 'service', 'oriented', 'architecture', '11g', 'implementation', 'specialist', 'oracle', 'cloud', 'solutions', 'specialist', 'sales', 'specialist', 'certifications', 'oracle', 'unified', 'business', 'process', 'management', '11g', 'certified', 'saas', 'oracle', 'hcm', 'cloud', 'oracle', 'field', 'service', 'cloud', 'specialist', 'paas', 'oracle', 'app', 'development', 'cloud', 'platform', 'oracle', 'db', 'cloud', 'accenture', 'senior', 'technology', 'architect', 'certification', 'services', 'oracle', 'app', 'integration', 'cloud', 'platform', 'completed', 'oracle', 'enterprise', 'architecture', 'framework', 'oeaf', 'iaas', 'oracle', 'cloud', 'machine', 'training', 'conducted', 'oracle', 'work', 'experience', 'summary', 'accenture', 'llp', 'usa', 'manager', 'senior', 'oracle', 'integration', 'architect', 'lead', 'mar', '2016', 'till', 'date', 'accenture', 'solutions', 'pvt', 'ltd', 'india', 'oracle', 'integration', 'architect', 'lead', 'associate', 'manager', 'jul', '2010', 'mar', '2016', 'patni', 'computer', 'systems', 'limited', 'igate', 'senior', 'software', 'specialist', 'feb', '2008', 'jul', '2010', 'keystone', 'sol', 'pvt', 'ltd', 'stg', 'mastek', 'project', 'leader', 'aug', '2007', 'jan', '2008', 'novartis', 'healthcare', 'pvt', 'ltd', 'global', 'sse', 'lead', 'mar', '2004', 'jul', '2007', 'niit', 'technologies', 'ltd', 'team', 'leader', 'feb', '1999', 'feb', '2002', 'burlingtons', 'exports', 'system', 'manager', 'jan', '1996', 'sep', '1998', 'academic', 'background', 'post', 'graduate', 'pgdit', 'symbiosis', 'pune', 'india', '2008', 'engineering', 'diploma', 'digital', 'electronics', 'bhagubai', 'polytechnic', 'mumbai', 'india', '1992', 'bachelor', 'bba', 'icfai', 'university', 'tripura', 'india', 'advanced', 'diploma', 'systems', 'management', 'niit', 'mumbai', 'india', '1994', 'high', 'school', 'c', 'c', 'r', 'oak', 'high', 'school', 'mumbai', 'india', '1988', 'current', 'work', 'experience', 'details', 'accenture', 'llp', 'usa', 'manager', 'senior', 'oracle', 'integration', 'architect', 'lead', 'mar', '2016', 'till', 'date', 'state', 'missouri', 'movers', 'cloud', 'transformation', 'program', 'client', 'state', 'missouri', 'technologies', 'oracle', 'cloud', 'erp', 'cloud', 'hcm', 'integration', 'cloud', 'oic', 'bi', 'reports', 'role', 'cloud', 'interface', 'lead', 'description', 'state', 'missouri', 'seeking', 'replacing', 'existing', 'prem', 'legacy', 'application', 'sam', 'ii', 'integrated', 'finance', 'hr', 'payroll', 'transforming', 'modern', 'centralized', 'cloud', 'based', 'erp', 'platform', 'known', 'movers', 'missouri', 'vital', 'enterprise', 'resource', 'system', 'state', 'missouri', 'movers', 'transformation', 'program', 'focuses', 'bringing', 'together', 'core', 'business', 'processes', 'unified', 'platform', 'across', 'agencies', 'departments', 'implementing', 'oracle', 'cloud', 'epm', 'budgeting', 'oracle', 'clou ...
# ----------------------------------------
# Heading: Projects
# Content: ['project', 'kpi', 'argus', 'sina', 'client', 'novartis', 'healthcare', 'pvt', 'ltd', 'technology', 'oracle', 'java', 'jsp', 'struts', 'reportnet', 'role', 'pl', 'sql', 'developer', 'analyst', 'lead', 'description', 'project', 'involved', 'design', 'development', 'sina', 'safety', 'information', 'notification', 'system', 'integrating', 'argus', 'safety', 'database', 'application', 'system', 'implemented', 'functionalities', 'collection', 'processing', 'safety', 'data', 'clinical', 'trials', 'post', 'marketing', 'reporting', 'adverse', 'events', 'related', 'data', 'fda', 'supported', 'global', 'nature', 'cs', 'e', 'workflow', 'functionality', 'produce', 'regulatory', 'reports', 'distribution', 'health', 'authorities', 'kpi', 'reports', 'management', 'purpose', 'responsibilities', 'understanding', 'business', 'needs', 'designing', 'reviewing', 'urs', 'frs', 'preparation', 'review', 'design', 'specifications', 'development', 'pl', 'sql', 'packages', 'procedures', 'functions', 'triggers', 'lead', 'project', 'oracle', 'development', 'reportnet', 'framework', 'modeling', 'reports', 'designing', 'fronts', 'niit', 'technologies', 'ltd', 'team', 'leader', 'feb', '1999', 'till', 'feb', '2002', 'notable', 'accomplishments', 'contributed', 'lead', 'application', 'development', 'projects', 'rcf', 'citibank', 'contribute', 'information', 'system', 'consulting', 'assignment', 'enterprise', 'architect', 'mhada', 'project', 'enterprise', 'resource', 'information', 'system', 'entris', 'client', 'rashtriya', 'chemicals', 'fertilizers', 'ltd', 'technology', 'oracle', '8', 'pb', '6', '5', 'rational', 'rose', 'role', 'analyst', 'programmer', 'team', 'leader', 'description', 'financial', 'accounting', 'system', 'core', 'totally', 'integrated', 'enterprise', 'resource', 'information', 'system', 'provides', 'every', 'financial', 'accounting', 'functionality', 'like', 'voucher', 'preparation', 'account', 'payables', 'account', 'receivables', 'finalizations', 'balance', 'sheet', 'preparation', 'rcf', 'ltd', 'across', '33', 'branches', 'tight', 'integration', 'systems', 'criticality', 'generate', 'accurate', 'balance', 'sheet', 'close', 'real', 'time', 'highlights', 'project', 'responsibilities', 'business', 'requirement', 'study', 'analysis', 'designing', 'case', 'modeling', 'rational', 'rose', 'db', 'modeling', 'designing', 'development', 'pb', 'oracle', 'packages', 'procedures', 'functions', 'triggers', 'leading', 'coordinating', 'planning', 'tracking', 'fixed', 'asset', 'module', 'team', 'project', 'human', 'resource', 'intranet', 'portal', 'e', 'hr', 'client', 'citibank', 'technology', 'oracle', '8i', 'html', 'java', 'script', 'jsp', 'ejb', 'role', 'database', 'modeler', 'designer', 'description', 'e', 'hr', 'web', 'based', 'intranet', 'portal', 'citibank', '40', 'ceemea', 'group', 'countries', 'across', 'world', 'purpose', 'facilitate', 'workflow', 'hr', 'functions', 'employees', 'across', 'globe', 'central', 'database', 'oracle', '8i', 'interface', 'citibank', 'applications', 'like', 'global', 'employee', 'management', 'system', 'gems', 'human', 'resources', 'payroll', 'system', 'hrps', 'security', 'management', 'system', 'sms', 'responsibilities', 'database', 'modeling', 'database', 'designing', 'burlingtons', 'exports', 'system', 'manager', 'jan', '1996', 'till', 'sep', '1998', 'notable', 'accomplishments', 'responsible', 'operation', 'company', 'including', 'software', 'hardware', 'network', 'related', 'activities', 'vendor', 'liaison', 'management', 'activities', 'day', 'day', 'requirements', 'departments', 'application', 'life', 'cycle', 'management', 'support', 'maintenance', 'upgrades', 'enhancements', 'strategy', 'roadmap', 'suite', 'application', 'modules', 'like', 'pre', 'shipment', 'production', 'shop', 'floor', 'post', 'shipment', 'payroll', 'etc', 'initiation', 'planning', 'execution', 'implementation', 'projects', 'towards', 'new', 'applications', 'development', 'enhancement', 'existing', 'applications', 'etc', 'project', 'g ...
# ----------------------------------------

# %%
import pdfplumber
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import os

# Preprocessing: load stopwords
stop_words = set(stopwords.words('english'))

# Function to preprocess text (remove punctuation, lowercase, tokenize, and remove stopwords)
def preprocess_text(text):
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'\W+', ' ', text)  # Remove punctuation
    words = word_tokenize(text)  # Tokenize
    words = [w for w in words if w not in stop_words]  # Remove stopwords
    return words

# Function to check if a line is likely to be a heading (based on structure)
def is_heading(line, next_line):
    # Consider the line a heading if it's shorter (less than 5 words)
    if len(line.split()) <= 5:
        # Additionally, headings often have no punctuation and are followed by content
        if len(next_line.split()) > 5:
            return True
    return False

# Function to extract text from text-based PDF using pdfplumber
def extract_text_from_pdf(pdf_path):
    all_text = []
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            text = page.extract_text()
            if text:
                all_text.extend(text.split("\n"))  # Split text into lines
    return all_text

# Function to dynamically extract headings and descriptions based on text structure
def extract_dynamic_headings(text_lines):
    result = {}
    current_heading = None
    current_content = []

    for i in range(len(text_lines) - 1):
        line = text_lines[i].strip()
        next_line = text_lines[i + 1].strip()  # Look ahead to the next line

        # Check if the current line is a heading
        if is_heading(line, next_line):
            # If we have accumulated content, store it under the previous heading
            if current_heading:
                result[current_heading] = ' '.join(current_content).strip()
                current_content = []  # Reset content buffer
            
            current_heading = line  # Set new heading
        else:
            if current_heading:  # Only accumulate content after a heading
                current_content.append(line)

    # Add the last section
    if current_heading:
        result[current_heading] = ' '.join(current_content).strip()

    return result

# Main function to handle text-based PDFs
def process_pdf(pdf_path):
    # Check if the file is valid
    if not os.path.exists(pdf_path):
        print(f"File {pdf_path} not found!")
        return
    else:
        print(f"Processing file: {pdf_path}")
    
    # Extract text with pdfplumber (for text-based PDFs)
    try:
        extracted_lines = extract_text_from_pdf(pdf_path)
        print(f"Extracted Text Lines: {extracted_lines[:10]}...")  # Show only first 10 lines for brevity
    except Exception as e:
        print(f"Error extracting text: {e}")
        return

    # Extract headings and descriptions dynamically
    heading_to_content = extract_dynamic_headings(extracted_lines)

    # Display the extracted headings and content
    if heading_to_content:
        for heading, content in heading_to_content.items():
            print(f"Heading: {heading}")
            print(f"Content: {content}")
            print("-" * 40)
    else:
        print("No headings and content extracted.")

# Example usage:
if __name__ == "__main__":
    pdf_path = "202308031905911_jessicatucker.docx"  # Replace with the path to your PDF
    process_pdf(pdf_path)
# Out:
# Processing file: 202308031905911_jessicatucker.docx
# Error extracting text: No /Root object! - Is this really a PDF?

# %%
import pdfplumber
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import os
import docx  # For handling Word documents

# Preprocessing: load stopwords
stop_words = set(stopwords.words('english'))

# Function to preprocess text (remove punctuation, lowercase, tokenize, and remove stopwords)
def preprocess_text(text):
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'\W+', ' ', text)  # Remove punctuation
    words = word_tokenize(text)  # Tokenize
    words = [w for w in words if w not in stop_words]  # Remove stopwords
    return words

# Function to check if a line is likely to be a heading (based on structure)
def is_heading(line, next_line):
    # Consider the line a heading if it's shorter (less than 5 words)
    if len(line.split()) <= 5:
        # Additionally, headings often have no punctuation and are followed by content
        if len(next_line.split()) > 5:
            return True
    return False

# Function to extract text from text-based PDF using pdfplumber
def extract_text_from_pdf(pdf_path):
    all_text = []
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            text = page.extract_text()
            if text:
                all_text.extend(text.split("\n"))  # Split text into lines
    return all_text

# Function to extract text from Word document using python-docx
def extract_text_from_docx(docx_path):
    all_text = []
    doc = docx.Document(docx_path)
    for para in doc.paragraphs:
        text = para.text.strip()
        if text:
            all_text.append(text)
    return all_text

# Function to dynamically extract headings and descriptions based on text structure
def extract_dynamic_headings(text_lines):
    result = {}
    current_heading = None
    current_content = []

    for i in range(len(text_lines) - 1):
        line = text_lines[i].strip()
        next_line = text_lines[i + 1].strip()  # Look ahead to the next line

        # Check if the current line is a heading
        if is_heading(line, next_line):
            # If we have accumulated content, store it under the previous heading
            if current_heading:
                result[current_heading] = ' '.join(current_content).strip()
                current_content = []  # Reset content buffer
            
            current_heading = line  # Set new heading
        else:
            if current_heading:  # Only accumulate content after a heading
                current_content.append(line)

    # Add the last section
    if current_heading:
        result[current_heading] = ' '.join(current_content).strip()

    return result

# Main function to handle both text-based PDFs and Word documents
def process_document(file_path):
    # Check if the file is valid
    if not os.path.exists(file_path):
        print(f"File {file_path} not found!")
        return
    else:
        print(f"Processing file: {file_path}")
    
    # Determine file type based on extension
    file_extension = os.path.splitext(file_path)[1].lower()

    # Extract text based on file type
    if file_extension == '.pdf':
        try:
            extracted_lines = extract_text_from_pdf(file_path)
            print(f"Extracted Text Lines: {extracted_lines[:10]}...")  # Show only first 10 lines for brevity
        except Exception as e:
            print(f"Error extracting text from PDF: {e}")
            return
    elif file_extension == '.docx':
        try:
            extracted_lines = extract_text_from_docx(file_path)
            print(f"Extracted Text Lines: {extracted_lines[:10]}...")  # Show only first 10 lines for brevity
        except Exception as e:
            print(f"Error extracting text from Word document: {e}")
            return
    else:
        print(f"Unsupported file format: {file_extension}")
        return

    # Extract headings and descriptions dynamically
    heading_to_content = extract_dynamic_headings(extracted_lines)

    # Display the extracted headings and content
    if heading_to_content:
        for heading, content in heading_to_content.items():
            print(f"Heading: {heading}")
            print(f"Content: {content}")
            print("-" * 40)
    else:
        print("No headings and content extracted.")

# Example usage:
if __name__ == "__main__":
    file_path = "202308031905911_jessicatucker.docx"  # Replace with the path to your file (PDF or DOCX)
    process_document(file_path)
# Out:
# Processing file: 202308031905911_jessicatucker.docx
# Extracted Text Lines: ['JESSICA TUCKER', 'EL Dorado Hills, CA 95762', '(916) 542-5545', 'Jessmommie1101@gmail.com', 'OBJECTIVE', 'To obtain a rewarding and challenging position as a Medical Biller/Coder or Office Assistant where a highly motivated and enthusiastic individual as myself can become a valuable member of a health care team.', 'EDUCATION', 'Carrington College\t\t\t\t\t\t\tPresent', 'AA-Associates in Health Studies', 'Carrington College\t\t\t\t\t\t\tNovember 2021']...
# Heading: OBJECTIVE
# Content: To obtain a rewarding and challenging position as a Medical Biller/Coder or Office Assistant where a highly motivated and enthusiastic individual as myself can become a valuable member of a health care team. EDUCATION Carrington College							Present AA-Associates in Health Studies Carrington College							November 2021 Medical Billing and Coding Certificate DeAnza College							December 2010 Web Design SKILLS/TRAINING/ABILITIES
# ----------------------------------------
# Heading: PROFESSIONAL EXPERIENCE
# Content: California Employment Development Department/Maximus– Sacramento, CA Fact Finding Agent/Employer Protests
# ----------------------------------------
# Heading: March 2022– Present
# Content: Responsible for reviewing unemployment insurance claims with outstanding Employer Protest Issues to determine next steps required to resolve those issues. Utilized critical thinking skills I analyzed all information, notes, and documentation to identify gaps or discrepancies in information. Performed outreach to claimants and/or employers to obtain necessary information, notate that in the claim file, and forward detailed notes required to resolve the issue. Time management skills used to work a caseload effectively and in order of priority set by leadership Critical thinking skills applied to identify the needs one each unique claim, and communication skills ensuring the information gathered is clearly notated in the claim Carrington College – Sacramento, CA			         December 2020 – November 2021
# ----------------------------------------
# Heading: Medical Billing and Coding Student
# Content: Gained skills to work as a medical biller/coder administrative secretary in healthcare. Demonstrated skills and knowledge necessary to perform medical coding and process medical insurance billing and claims within the health care setting. Performed clerical functions and communicate with other professionals, patients, and visitors in the health care setting. Apply critical thinking, collaboration, and communication. Centene/Tricare –				                   		     April 2021 – September 2021
# ----------------------------------------
# Heading: Customer Service Representative/Temporary
# Content: Provider CPT code utilization to provide authorization approval status, assisted in referrals, authorizations, and providing eligibility information regarding patient Tricare coverage. Assisted beneficiaries and their dependents with health insurance information including pcm and MTF (military treatment facilities), eligibility, enrollment, provider changes, referrals, authorizations, copay/coinsurance information, point of service options and price quotes. Trained in medical systems OMNI & Care Radius utilizing a government protected VDI desktop. El Dorado Hills Library – El Dorado Hills, CA			                 March 2019 – Present
# ----------------------------------------
# Heading: Volunteer
# Content: Assisted visitors in conducting research and locating resources. Shelved books according to catalog sequencing. Provided pick lists, special orders, and amazon sales. Comcast – CA		                   		          			                 2007 – 2009
# ----------------------------------------
# Heading: Customer Service Representative
# Content: Customer service, inbound calls, assisting customers with light IT issues, billing questions, service calls, and new services in a timely and professional manner. Blue Cross/Blue Shield – CA	                   			         			  2007
# ----------------------------------------
# Heading: Medical New Enrollment Specialist
# Content: Processing new enrollments by entering all patient data, verifying information under HIPPA regulations and authorizations with account and billing reps. Sacramento Public Library – Sacramento, CA		                   		              2007
# ----------------------------------------
# Heading: Library Assistant
# Content: Working with patrons, shelving, check in and check out procedures, inventory, open and closing procedures. Customer service, light IT support and subject/book research. Healthnet –				                   		    				 2005
# ----------------------------------------
# Heading: Enrollment Specialist
# Content: Enrollment specialist who working with healthcare billing departments to makes sure patients were enrolled and receiving the appropriate coverage for covered services. Data entry, being aware of individual coverage options and copays, making sure all patient information is up to date, sharing limited healthcare information under HIPPA regulations and validating coverage through medical practices and physician/medical assistants and coders. Volunteer Positions August 2018-Present
# ----------------------------------------
# Heading: Oak Meadow Elementary School,
# Content: Kindergarten and Second grade Teacher volunteer
# ----------------------------------------
# Heading: 2009-2019
# Content:
# ----------------------------------------
